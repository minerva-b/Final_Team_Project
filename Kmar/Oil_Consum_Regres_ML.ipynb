# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

oil = pd.read_csv('../data/clean_data/Oil Consumption - Barrels-YearFixed-Python.csv')
oil.head()
# Out:
#    Year  Argentina  Austria  Azerbaijan  Belarus  Belgium  Brazil  Bulgaria  \
# 0  1965     432.37   106.65         NaN      NaN   312.11  305.67     71.22
# 1  1966     447.27   118.21         NaN      NaN   318.67  334.60     81.13
# 2  1967     459.88   125.65         NaN      NaN   350.40  344.54    101.83
# 3  1968     468.99   144.32         NaN      NaN   405.10  412.43    120.46
# 4  1969     491.75   158.69         NaN      NaN   468.29  456.56    148.47
#
#     Canada  Central America  ...  Total World  Trinidad & Tobago  Turkey  \
# 0  1108.12            78.48  ...        22.69              35.17   69.37
# 1  1167.47            79.31  ...        24.73              35.42   82.81
# 2  1245.56            83.42  ...        26.55              36.95   97.02
# 3  1322.16            84.86  ...        28.96              37.56  116.57
# 4  1380.19            90.34  ...        31.80              39.49  129.44
#
#    Turkmenistan  Ukraine  United Kingdom        US     USSR  Uzbekistan  \
# 0           NaN      NaN         1466.08  11522.19  3313.95         NaN
# 1           NaN      NaN         1573.60  12100.35  3548.82         NaN
# 2           NaN      NaN         1696.27  12566.88  3866.13         NaN
# 3           NaN      NaN         1794.16  13404.55  4107.31         NaN
# 4           NaN      NaN         1930.18  14152.99  4376.25         NaN
#
#    Venezuela
# 0     183.88
# 1     181.47
# 2     185.73
# 3     201.43
# 4     200.37
#
# [5 rows x 69 columns]

# %%
pop = pd.read_csv('../data/clean_data/WorldPopulationbyYear.csv')
pop
# Out:
#     Year  World Population
# 0   1950        2556506575
# 1   1951        2593857923
# 2   1952        2635733945
# 3   1953        2681061562
# 4   1954        2729285853
# ..   ...               ...
# 65  2015        7338964960
# 66  2016        7424282488
# 67  2017        7509065705
# 68  2018        7591932907
# 69  2019        7673533972
#
# [70 rows x 2 columns]

# %%
oil_pop = pop.merge(oil, on="Year")
oil_pop
# Out:
#     Year  World Population  Argentina  Austria  Azerbaijan  Belarus  Belgium  \
# 0   1965        3322973367     432.37   106.65         NaN      NaN   312.11
# 1   1966        3393031801     447.27   118.21         NaN      NaN   318.67
# 2   1967        3462460201     459.88   125.65         NaN      NaN   350.40
# 3   1968        3532826854     468.99   144.32         NaN      NaN   405.10
# 4   1969        3607499991     491.75   158.69         NaN      NaN   468.29
# 5   1970        3682911039     447.79   175.71         NaN      NaN   511.71
# 6   1971        3760509002     479.60   196.21         NaN      NaN   525.21
# 7   1972        3836892580     478.58   211.86         NaN      NaN   566.89
# 8   1973        3912347640     482.63   230.40         NaN      NaN   597.90
# 9   1974        3988478324     482.87   207.13         NaN      NaN   529.36
# 10  1975        4062864562     457.95   209.78         NaN      NaN   503.77
# 11  1976        4135418002     472.73   225.93         NaN      NaN   523.62
# 12  1977        4207766711     497.94   218.23         NaN      NaN   516.78
# 13  1978        4281312782     499.88   236.52         NaN      NaN   551.44
# 40        108.97   295.66         1830.52  20531.54      NaN      103.16
# 41        105.34   308.33         1810.42  20312.81      NaN      103.01
# 42        111.15   308.09         1746.12  20208.27      NaN       94.33
# 43        113.60   298.93         1703.87  18840.73      NaN       92.63
# 44        106.23   282.37         1626.75  18030.47      NaN       88.74
# 45        117.92   267.21         1604.25  18324.38      NaN       75.63
# 46        124.63   278.08         1573.26  17983.22      NaN       70.96
# 47        129.39   267.41         1521.84  17593.72      NaN       63.49
# 48        137.37   255.51         1504.83  18005.84      NaN       60.10
# 49        143.28   219.19         1505.81  18136.22      NaN       56.63
# 50        144.60   193.11         1552.44  18523.68      NaN       52.69
# 51        142.89   203.70         1596.84  18617.64      NaN       48.62
# 52        143.67   208.46         1610.23  18883.34      NaN       46.76
# 53        148.82   206.82         1584.04  19427.64      NaN       45.16
# 54        161.83   221.84         1544.74  19399.96      NaN       43.66
#
#     Venezuela
# 0      183.88
# 1      181.47
# 2      185.73
# 3      201.43
# 4      200.37
# 5      209.87
# 6      212.34
# 7      230.82
# 8      257.26
# 9      259.42
# 10     275.92
# 11     280.30
# 12     314.79
# 13     330.87
# 14     354.43
# 15     423.40
# 16     448.34
# 17     444.54
# 18     435.24
# 19     408.38
# 20     418.09
# 21     435.20
# 22     418.92
# 23     433.39
# 24     422.65
# 25     427.93
# 26     412.73
# 27     488.10
# 28     450.24
# 29     498.64
# 30     484.03
# 31     403.33
# 32     432.11
# 33     474.20
# 34     506.74
# 35     510.46
# 36     572.23
# 37     602.74
# 38     506.52
# 39     544.71
# 40     605.78
# 41     667.58
# 42     640.29
# 43     716.09
# 44     726.23
# 45     725.42
# 46     737.20
# 47     792.13
# 48     782.46
# 49     720.01
# 50     637.02
# 51     537.33
# 52     462.86
# 53     402.43
# 54     355.77
#
# [55 rows x 70 columns]

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = oil_pop["World Population"][15:36].values.reshape(-1, 1)
y = oil_pop["Total World"][15:36].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (21, 1) (21, 1)

# %%
X
# Out:
# array([[4432925590],
#        [4511137170],
#        [4592341169],
#        [4674266079],
#        [4755914211],
#        [4839074592],
#        [4924736807],
#        [5012555212],
#        [5101297281],
#        [5189996799],
#        [5280076284],
#        [5368065408],
#        [5452349932],
#        [5537511534],
#        [5621787194],
#        [5706689090],
#        [5789623839],
#        [5872254361],
#        [5954005524],
#        [6034491778],
#        [6114332536]], dtype=int64)

# %%
# Plot the data to see if a linear trend exists

### BEGIN SOLUTION
# plt.scatter(X, y)
oil_pop.plot(kind = "line", x="Year", y="Total World")

# plt.ylabel("Barrels")
### END SOLUTION

# %%
oil_pop.plot(kind = "line", x="Year", y="World Population")

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
world_pop_2000 = oil_pop['World Population'][36].reshape(-1, 1)
world_pop_2000.shape
# Out:
# (1, 1)

# %%
barrels_2000 = oil_pop['Total World'][36].reshape(-1, 1)
barrels_2000.shape
# Out:
# (1, 1)

# %%
from sklearn.metrics import mean_squared_error, r2_score
fitment = model.fit(X, y)
# r2 = r2_score(barrels_2000, predicted)

# %%
from sklearn.metrics import mean_squared_error, r2_score

### BEGIN SOLUTION

# Use our model to make predictions
# predicted = model.predict(X_test)

# mse = mean_squared_error(barrels_2000, predicted)
# r2 = r2_score(barrels_2000, predicted)
# Score the predictions with mse and r2
# mse = mean_squared_error(y_test, predicted)
# r2 = r2_score(y_test, predicted)

# print(f"Mean Squared Error (MSE): {mse}")
# print(f"R-squared (R2): {r2}")

predicted = fitment.predict(world_pop_2000)

print(f"Prediction: {predicted}")
print(f"Actual: {barrels_2000}")
# Out:
# Prediction: [[87.1299232]]
# Actual: [[87.59]]

# %%
fitment.predict(oil_pop['World Population'].to_numpy().reshape(-1, 1))
# Out:
# array([[ 26.82990627],
#        [ 28.301508  ],
#        [ 29.75987564],
#        [ 31.23795162],
#        [ 32.80648679],
#        [ 34.39052203],
#        [ 36.02049418],
#        [ 37.62495776],
#        [ 39.20991749],
#        [ 40.80906893],
#        [ 42.37157769],
#        [ 43.89558788],
#        [ 45.41529763],
#        [ 46.96015839],
#        [ 48.54466006],
#        [ 50.14483806],
#        [ 51.78769945],
#        [ 53.49341764],
#        [ 55.21427881],
#        [ 56.92932617],
#        [ 58.67613884],
#        [ 60.47550341],
#        [ 62.32015949],
#        [ 64.18421746],
#        [ 66.04738163],
#        [ 67.93953249],
#        [ 69.78777458],
#        [ 71.55820027],
#        [ 73.34704929],
#        [ 75.11728878],
#        [ 76.90068258],
#        [ 78.64275578],
#        [ 80.37843858],
#        [ 82.09565014],
#        [ 83.78629185],
#        [ 85.46337469],
#        [ 87.1299232 ],
#        [ 88.79105099],
#        [ 90.45319123],
#        [ 92.12667218],
#        [ 93.81123219],
#        [ 95.51237491],
#        [ 97.22366198],
#        [ 98.96110343],
#        [100.69732939],
#        [102.42601337],
#        [104.12721523],
#        [105.86861741],
#        [107.63047732],
#        [109.40728256],
#        [111.18720391],
#        [112.9793282 ],
#        [114.76022911],
#        [116.50088346],
#        [118.21494216]])

# %%
oil_pop.loc[oil_pop['Year'].between(1980, 2000), ['World Population', 'Total World']]
# Out:
#     World Population  Total World
# 15        4432925590        51.26
# 16        4511137170        51.82
# 17        4592341169        52.09
# 18        4674266079        52.93
# 19        4755914211        57.25
# 20        4839074592        58.54
# 21        4924736807        59.11
# 22        5012555212        62.21
# 23        5101297281        65.12
# 24        5189996799        67.93
# 25        5280076284        70.14
# 26        5368065408        71.91
# 27        5452349932        72.24
# 28        5537511534        72.97
# 29        5621787194        73.42
# 30        5706689090        75.99
# 31        5789623839        79.79
# 32        5872254361        79.32
# 33        5954005524        80.78
# 34        6034491778        83.07
# 35        6114332536        86.40

# %%
# Make for loop to run predictions from 2001 - 2010
# Move window 1 year ahead
predict0110=[]
actual0110=[]

# for index, row in oil_pop.iterrows():
#     for item in i:
#     Reshape the row's world pop and total world barrels
#     fitment.predict(oil_pop['World Population'].to_numpy().reshape(-1, 1))
#     pop_loop = row['World Population'].reshape(-1, 1)
#     barrels_loop = row['Total World'].reshape(-1, 1)
#     predicted_loop = fitment.predict(pop_loop)
#     # Append to empty lists
#     predict0110.append(predicted_loop)
#     actual0110.append(barrels_loop)

for year in range(20):
    start = 1980 + year
    end = 2000 + year
    
#     print(start)
#     print(end)
    xy = oil_pop.loc[oil_pop['Year'].between(start, end), ['World Population', 'Total World']]
    X = xy["World Population"].values.reshape(-1, 1)
    y = xy["Total World"].values.reshape(-1, 1)
    fitment = model.fit(X, y)
    oil_predict = fitment.predict(xy['World Population'].iloc[20].reshape(-1, 1))
    print(oil_predict)
    predict0110.append(oil_predict)
#     print(xy['World Population'].iloc[20])
#     barrels_loop = fitment.predict(xy['Total World'].to_numpy().reshape(-1, 1))
# Out:
# [[85.46337469]]
# [[87.31088247]]
# [[89.22366941]]
# [[91.13499494]]
# [[93.24939439]]
# [[95.70151539]]
# [[98.2238244]]
# [[100.99126676]]
# [[103.93381876]]
# [[106.17405982]]
# [[109.53678841]]
# [[112.96431793]]
# [[116.53776318]]
# [[119.88750738]]
# [[122.80457757]]
# [[125.60243969]]
# [[128.47798602]]
# [[131.64171358]]
# [[135.25748229]]
# [[138.6880653]]

# %%
# Use code above but change for loop for rolling window average

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

from sklearn.metrics import mean_squared_error, r2_score

### BEGIN SOLUTION

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
print(f"Prediction: {predicted}")

### END SOLUTION

# %%
for prediction, actual in zip(predicted, y_test):
    print(f"Error: {prediction - actual}")

# %%
predict_list = []
for prediction in predicted:
    for p in prediction:
        predict_list.append(p)
predict_list

# %%
actual_list = []
for actual in y_test:
    for a in actual:
        actual_list.append(a)
actual_list

# %%
predict_actual_df = pd.DataFrame(actual_list, predict_list).reset_index()
predict_actual_df = predict_actual_df.rename(columns={"index": "Prediction", 0: "Actual"})
predict_actual_df['Error'] = predict_actual_df['Prediction'] - predict_actual_df['Actual']
predict_actual_df

# %%
mean_err = predict_actual_df['Error'].mean()
mean_err

# %%
list(zip(predicted, y_test))

# %%
for p in predicted:
    print(p)

# %%
fill=[]
for x in range[10:20]:
    
model.predict([[fill]])

# %%
year2020 = model.predict([[2020], [2021]])
year2020
# year2021 = model.predict([[2021]])
# year2022 = model.predict([[2022]])
# year2023 = model.predict([[2023]])
# year2024 = model.predict([[2024]])

# %%
# Call the `score` method on the model to show the r2 score

### BEGIN SOLUTION
model.score(X_test, y_test)
### END SOLUTION
