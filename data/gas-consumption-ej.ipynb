# %%
import pandas as pd
import numpy as np

# %%
gas = "gas-consumption-ej.csv"

# %%
gas_df  = pd.read_csv(gas)
gas_df
# Out:
#               Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 0                Canada   0.78   0.85   0.91   1.01   1.13   1.25   1.33
# 1                Mexico   0.29   0.31   0.26   0.28   0.35   0.36   0.37
# 2                    US  14.97  16.14  17.04  18.24  19.63   20.7  21.34
# 3   Total North America  16.04   17.3  18.21  19.53  21.11   22.3  23.04
# 4             Argentina   0.15   0.16   0.17   0.19   0.19   0.21   0.23
# ..                  ...    ...    ...    ...    ...    ...    ...    ...
# 95             Thailand      -      -      -      -      -      -      -
# 96              Vietnam      -      -      -      -      -      -      -
# 97   Other Asia Pacific   0.01   0.01   0.02   0.02   0.02   0.02   0.02
# 98   Total Asia Pacific    0.2   0.22   0.26   0.28   0.37   0.51   0.61
# 99          Total World  22.69  24.73  26.55  28.96   31.8  34.61  37.05
#
#      1972   1973  ...    2013    2014    2015    2016    2017    2018    2019  \
# ...

# %%
clean1 = gas_df.replace(np.nan,0)
clean1
# Out:
#               Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 0                Canada   0.78   0.85   0.91   1.01   1.13   1.25   1.33
# 1                Mexico   0.29   0.31   0.26   0.28   0.35   0.36   0.37
# 2                    US  14.97  16.14  17.04  18.24  19.63   20.7  21.34
# 3   Total North America  16.04   17.3  18.21  19.53  21.11   22.3  23.04
# 4             Argentina   0.15   0.16   0.17   0.19   0.19   0.21   0.23
# ..                  ...    ...    ...    ...    ...    ...    ...    ...
# 95             Thailand      -      -      -      -      -      -      -
# 96              Vietnam      -      -      -      -      -      -      -
# 97   Other Asia Pacific   0.01   0.01   0.02   0.02   0.02   0.02   0.02
# 98   Total Asia Pacific    0.2   0.22   0.26   0.28   0.37   0.51   0.61
# 99          Total World  22.69  24.73  26.55  28.96   31.8  34.61  37.05
#
#      1972   1973  ...    2013    2014    2015    2016    2017    2018    2019  \
# ...

# %%
clean2 = clean1.replace('-', np.nan)
clean2
# Out:
#               Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 0                Canada   0.78   0.85   0.91   1.01   1.13   1.25   1.33
# 1                Mexico   0.29   0.31   0.26   0.28   0.35   0.36   0.37
# 2                    US  14.97  16.14  17.04  18.24  19.63   20.7  21.34
# 3   Total North America  16.04   17.3  18.21  19.53  21.11   22.3  23.04
# 4             Argentina   0.15   0.16   0.17   0.19   0.19   0.21   0.23
# ..                  ...    ...    ...    ...    ...    ...    ...    ...
# 95             Thailand    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 96              Vietnam    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 97   Other Asia Pacific   0.01   0.01   0.02   0.02   0.02   0.02   0.02
# 98   Total Asia Pacific    0.2   0.22   0.26   0.28   0.37   0.51   0.61
# 99          Total World  22.69  24.73  26.55  28.96   31.8  34.61  37.05
#
#      1972   1973  ...    2013    2014    2015    2016    2017    2018    2019  \
# ...

# %%
clean2.to_csv ('./clean_data/final_gas-consumption-ej.csv')
