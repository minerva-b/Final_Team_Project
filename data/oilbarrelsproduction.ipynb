# %%
import pandas as pd

# %%
oil_barrels = "oil-production-barrels.csv"

# %%
oil_barrels_df  = pd.read_csv(oil_barrels)
oil_barrels_df
# Out:
#    Thousand barrels daily   1965   1966   1967   1968   1969   1970   1971  \
# 0                  Canada    920   1012   1106   1194   1306   1473   1582
# 1                  Mexico    362    370    411    439    461    487    486
# 2                      US   9014   9579  10219  10600  10828  11297  11156
# 3     Total North America  10296  10961  11736  12233  12595  13257  13224
# 4               Argentina    276    293    319    348    362    399    432
# ..                    ...    ...    ...    ...    ...    ...    ...    ...
# 59               Thailand    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 60                Vietnam    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 61     Other Asia Pacific     35     34     31     35     36     40     42
# 62     Total Asia Pacific    899   1002   1063   1240   1432   1979   2387
# 63            Total World  31792  34561  37104  40418  43649  48075  50785
#
# ...
