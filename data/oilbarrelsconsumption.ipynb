# %%
import pandas as pd
import numpy as np

# %%
oil_barrels = "oil-production-consumption.csv"

# %%
oil_barrels_df  = pd.read_csv(oil_barrels)
oil_barrels_df
# Out:
#    Thousand barrels daily     1965     1966     1967     1968     1969  \
# 0                  Canada   1108.0   1167.0   1246.0   1322.0   1380.0
# 1                  Mexico    316.0    333.0    357.0    386.0    410.0
# 2                      US  11522.0  12100.0  12567.0  13405.0  14153.0
# 3     Total North America  12946.0  13601.0  14170.0  15113.0  15943.0
# 4               Argentina    432.0    447.0    460.0    469.0    492.0
# ..                    ...      ...      ...      ...      ...      ...
# 95               Thailand     48.0     56.0     62.0     81.0     88.0
# 96                Vietnam     31.0     69.0    100.0    102.0    124.0
# 97     Other Asia Pacific     60.0     63.0     67.0     71.0     75.0
# 98     Total Asia Pacific   3205.0   3693.0   4300.0   4902.0   5715.0
# 99            Total World  30771.0  33137.0  35503.0  38420.0  41727.0
#
#        1970     1971     1972     1973  ...     2013     2014     2015  \
# ...

# %%
clean1 = oil_barrels_df.replace(np.nan,0)
clean1
# Out:
#    Thousand barrels daily     1965     1966     1967     1968     1969  \
# 0                  Canada   1108.0   1167.0   1246.0   1322.0   1380.0
# 1                  Mexico    316.0    333.0    357.0    386.0    410.0
# 2                      US  11522.0  12100.0  12567.0  13405.0  14153.0
# 3     Total North America  12946.0  13601.0  14170.0  15113.0  15943.0
# 4               Argentina    432.0    447.0    460.0    469.0    492.0
# ..                    ...      ...      ...      ...      ...      ...
# 95               Thailand     48.0     56.0     62.0     81.0     88.0
# 96                Vietnam     31.0     69.0    100.0    102.0    124.0
# 97     Other Asia Pacific     60.0     63.0     67.0     71.0     75.0
# 98     Total Asia Pacific   3205.0   3693.0   4300.0   4902.0   5715.0
# 99            Total World  30771.0  33137.0  35503.0  38420.0  41727.0
#
#        1970     1971     1972     1973  ...     2013     2014     2015  \
# ...

# %%
clean2 = clean1.replace('-', np.nan)
clean2
# Out:
#    Thousand barrels daily     1965     1966     1967     1968     1969  \
# 0                  Canada   1108.0   1167.0   1246.0   1322.0   1380.0
# 1                  Mexico    316.0    333.0    357.0    386.0    410.0
# 2                      US  11522.0  12100.0  12567.0  13405.0  14153.0
# 3     Total North America  12946.0  13601.0  14170.0  15113.0  15943.0
# 4               Argentina    432.0    447.0    460.0    469.0    492.0
# ..                    ...      ...      ...      ...      ...      ...
# 95               Thailand     48.0     56.0     62.0     81.0     88.0
# 96                Vietnam     31.0     69.0    100.0    102.0    124.0
# 97     Other Asia Pacific     60.0     63.0     67.0     71.0     75.0
# 98     Total Asia Pacific   3205.0   3693.0   4300.0   4902.0   5715.0
# 99            Total World  30771.0  33137.0  35503.0  38420.0  41727.0
#
#        1970     1971     1972     1973  ...     2013     2014     2015  \
# ...

# %%
clean2.to_csv ('./clean_data/final_oil_barrel_consumption.csv')
