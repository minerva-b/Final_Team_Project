# %%
import pandas as pd
import numpy as np
import os

# %%
inital_df = "../notebook_data/Inflation, consumer prices (annual %).csv"

# %%
#Read CVS
df1  = pd.read_csv(inital_df)
df1
# Out:
#      Country Name Country Code                         Indicator Name  \
# 0           Aruba          ABW  Inflation, consumer prices (annual %)
# 1     Afghanistan          AFG  Inflation, consumer prices (annual %)
# 2          Angola          AGO  Inflation, consumer prices (annual %)
# 3         Albania          ALB  Inflation, consumer prices (annual %)
# 4         Andorra          AND  Inflation, consumer prices (annual %)
# ..            ...          ...                                    ...
# 259        Kosovo          XKX  Inflation, consumer prices (annual %)
# 260   Yemen, Rep.          YEM  Inflation, consumer prices (annual %)
# 261  South Africa          ZAF  Inflation, consumer prices (annual %)
# 262        Zambia          ZMB  Inflation, consumer prices (annual %)
# 263      Zimbabwe          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961     1962      1963     1964      1965  \
# ...

# %%
#Remove characters from dataframe
clean1 = df1.replace('-', np.nan)
clean1
# Out:
#      Country Name Country Code                         Indicator Name  \
# 0           Aruba          ABW  Inflation, consumer prices (annual %)
# 1     Afghanistan          AFG  Inflation, consumer prices (annual %)
# 2          Angola          AGO  Inflation, consumer prices (annual %)
# 3         Albania          ALB  Inflation, consumer prices (annual %)
# 4         Andorra          AND  Inflation, consumer prices (annual %)
# ..            ...          ...                                    ...
# 259        Kosovo          XKX  Inflation, consumer prices (annual %)
# 260   Yemen, Rep.          YEM  Inflation, consumer prices (annual %)
# 261  South Africa          ZAF  Inflation, consumer prices (annual %)
# 262        Zambia          ZMB  Inflation, consumer prices (annual %)
# 263      Zimbabwe          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961     1962      1963     1964      1965  \
# ...

# %%
#Replace Nan with Zeros from dataframe
clean2 = clean1.replace(np.nan,0)
clean2
# Out:
#      Country Name Country Code                         Indicator Name  \
# 0           Aruba          ABW  Inflation, consumer prices (annual %)
# 1     Afghanistan          AFG  Inflation, consumer prices (annual %)
# 2          Angola          AGO  Inflation, consumer prices (annual %)
# 3         Albania          ALB  Inflation, consumer prices (annual %)
# 4         Andorra          AND  Inflation, consumer prices (annual %)
# ..            ...          ...                                    ...
# 259        Kosovo          XKX  Inflation, consumer prices (annual %)
# 260   Yemen, Rep.          YEM  Inflation, consumer prices (annual %)
# 261  South Africa          ZAF  Inflation, consumer prices (annual %)
# 262        Zambia          ZMB  Inflation, consumer prices (annual %)
# 263      Zimbabwe          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961     1962      1963     1964      1965  \
# ...

# %%
# #Remove Zeros from dataframe
# clean3 = clean2[(clean2 != 0).all(1)]
# clean3

# %%
#Remove unnecessary columns from dataframe
clean4 = clean2.drop(columns=['Country Code','Indicator Name','Indicator Code'])
clean4
# Out:
#      Country Name      1960      1961     1962      1963     1964      1965  \
# 0           Aruba  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 1     Afghanistan  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 2          Angola  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 3         Albania  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 4         Andorra  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# ..            ...       ...       ...      ...       ...      ...       ...
# 259        Kosovo  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 260   Yemen, Rep.  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 261  South Africa  1.288878  2.102343  1.24629  1.337968  2.53498  4.069023
# 262        Zambia  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 263      Zimbabwe  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
#
# ...

# %%
# Rename columns
clean5 = clean4.rename(columns = {'Country Name': 'Year'}, inplace = False)
clean5
# Out:
#              Year      1960      1961     1962      1963     1964      1965  \
# 0           Aruba  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 1     Afghanistan  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 2          Angola  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 3         Albania  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 4         Andorra  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# ..            ...       ...       ...      ...       ...      ...       ...
# 259        Kosovo  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 260   Yemen, Rep.  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 261  South Africa  1.288878  2.102343  1.24629  1.337968  2.53498  4.069023
# 262        Zambia  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
# 263      Zimbabwe  0.000000  0.000000  0.00000  0.000000  0.00000  0.000000
#
# ...

# %%
#Transpose data for final file
Final_Clean_Transposed = clean5.set_index("Year").T
Final_Clean_Transposed
# Out:
# Year     Aruba  Afghanistan     Angola     Albania  Andorra  Arab World  \
# 1960  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1961  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1962  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1963  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1964  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1965  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1966  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1967  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1968  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1969  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1970  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# 1971  0.000000     0.000000   0.000000    0.000000      0.0    0.000000
# ...

# %%
#Export Final data set
Final_Clean_Transposed.to_csv ('../final_clean_data/InflationAnnual%-YearFixed-Python.csv')
